# %% [markdown]
# <a href="https://colab.research.google.com/github/kwanda2426/projects/blob/main/ML_In_Chem/UsingRDKit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Using RDKit** - Kwanda Mazibuko stdnr : 1077167

# %% [markdown]
# <div style="text-align: center;">
#    <img src="https://gdb.unibe.ch/content/images/2021/10/rdkit.png" >
# </div>

# %% [markdown]
# # **Import RDKit Library**

# %%
# !pip install rdkit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.2/36.2 MB 33.6 MB/s eta 0:00:00
# ...

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors
from rdkit import Chem
from rdkit.Chem import Draw
import pandas as pd
from IPython.display import display

import numpy as np
import pandas as pd

# %% [markdown]
# # **Import Data**

# %%
# Reading data
url = "https://raw.githubusercontent.com/kwanda2426/projects/main/ML_In_Chem/solubility.csv"
df = pd.read_csv(url)
df.head()
# Out:
#   Compound ID  Minimum Degree  Molecular Weight  Number of H-Bond Donors  \
# 0   Amigdalin               1           457.432                        7
# 1    Fenfuram               1           201.225                        1
# 2      citral               1           152.237                        0
# 3      Picene               2           278.354                        0
# 4   Thiophene               2            84.143                        0
#
#    Number of Rings  Number of Rotatable Bonds  Polar Surface Area  \
# 0                3                          7              202.32
# 1                2                          2               42.24
# 2                0                          4               17.07
# 3                5                          0                0.00
# 4                1                          0                0.00
#
#    measured log solubility in mols per litre  \
# 0                                      -0.77
# ...

# %% [markdown]
# # **Molecular Information**

# %% [markdown]
# Using [PubChem database](https://www.example.com) to access the SMILES representations of
# - Propane
# - Ethene
# - Cyclohexane
# - Buckminsterfullerene
#
# molecules.

# %% [markdown]
# [PubChem database](https://www.example.com)

# %% [markdown]
# # **Drawing molecules**

# %% [markdown]
# The first six molecules come from the Delaney dataset (solubility.csv).

# %%
# First six molecules
df_6 = df[['Compound ID','smiles']][:6]
df_6
# Out:
#      Compound ID                                             smiles
# 0      Amigdalin  OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)...
# 1       Fenfuram                             Cc1occc1C(=O)Nc2ccccc2
# 2         citral                               CC(C)=CCCC(C)=CC(=O)
# 3         Picene                 c1ccc2c(c1)ccc3c2ccc4c5ccccc5ccc43
# 4      Thiophene                                            c1ccsc1
# 5  benzothiazole                                     c2ccc1scnc1c2

# %%
# First six molecules
smiles_list = df_6["smiles"][:6]
compound_ids = df_6["Compound ID"][:6]

# Convert SMILES to RDKit molecule objects
mols = [Chem.MolFromSmiles(smile) for smile in smiles_list]

# Create a grid with labels
img = Draw.MolsToGridImage(
    mols,
    molsPerRow=3,
    subImgSize=(300, 300),
    legends=[str(cid) for cid in compound_ids]
)

# Display molecules grid
display(img)
